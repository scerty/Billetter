# %% [markdown]
# <a href="https://colab.research.google.com/github/scerty/Billetter/blob/master/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Oppgave1** :
#
# (a):
#
# Vi bruker bevegelsesligningen nr 4
#
# - $2\vec{a}\cdot \vec{S}=v^2-v^2_0$
#
# - $2a_y\cdot S_y=v^2_y-v^2_{y0}$
#
# - $ ⇒  -2g\cdot S_y=v^2_y-v^2_{y0}$
#
# - $ ⇒  S_y=\frac{v^2_{y0}-v^2_y}{2g}$
#
# - $ ⇒  v_{y0}=v_0 \cdot sin θ $ ,  $v_y=0$
#
# - $ ⇒  S_y=\frac{(v_0 \cdot sin θ)^2}{2g} =\frac{(20 \cdot sin 37)^2}{2 \cdot 9.81} = \frac{144.87}{19.62}=7.4m$
# ___
# (b):
#
# $v=v_{x0}=v_0 \cdot cos θ=20 \cdot cos 37=15.97m$
# ___
# (c):
#
# $2 \cdot  \vec{a}\cdot \vec{S}=\vec{v^2}-\vec{v^2_0}=2 \cdot g \cdot S=v^2-v^2_0$
#
# $v^2_{y}-v^2_{y0}=-2 \cdot g \cdot s_y $
#
# $-2 \cdot g \cdot s_y=0 ⇒ \pm \sqrt{v^2_{y0}}=\pm v^2_{y0}= \pm V_0 sin θ = \pm 12.036 \cdot  m/s$
#
# $v=\sqrt{v^2_{y}+v^2_{x}}=\sqrt{12.036^2+15.97^2}\approx
#  20 \cdot m/s$
# ___
# (d):
#
# $\vec{S}=\vec{v_0} \cdot t + \frac{1}{2} \vec{a} \cdot t^2$
#
# $S_y=v_{y0} \cdot t + \frac{1}{2} a_y \cdot t^2$
#
# $0= t(v_{y0}-\frac{1}{2} g \cdot t)$
#
# - $⇒ t_1=0$
# - $⇒ v_{y0}=\frac{1}{2} g \cdot t ⇒ t = \frac {v_{y0}}{g}=2.45 \cdot s$
# - $⇒ t_3=umulig$
#
# ___
# (e):
#
# $S_x=v_x \cdot t$
#
# $v_x=v_{x0}=15,97 \cdot m/s$
#
# $ S_x=15.97 \cdot 2.45=39.18 \cdot m$
#
# ___
# (f):
#
# $t= \frac {2 \cdot v_{y0}}{g}$
#
# $S_x=v_{x0} \cdot \frac{2 \cdot v_{y0} }{g}= \frac{2(v_0 \cdot sin θ)(v_0 \cdot cos θ)}{g} = \frac{v_0^2( 2 sin θ \cdot cos θ)}{g}$
#
# $ ⇒ S_x=\frac{v_0^2sin2 θ}{g}$
# ___
# (g):
#
# $S=S_x=65 \cdot 1000 \cdot m$
#
# $  S_x=\frac{v_0^2sin2 θ}{g}$
#
# $  65 \cdot 10^3=\frac{10^6 \cdot sin2 θ}{9.81}$
#
# $sin2 θ=\frac{9.81 \cdot 65 \cdot 10^3 }{10^6}=0.638$
#
#
# $2 θ_1=sin^{-1}(0.638) $  , $2 θ_2=180-sin^{-1}(0.638) $
#
# $θ_1=19.8° $ , $θ_2=70° $
#
#
# ___
# (h):
#
# $(S_x)'=\frac{-2v_0^2cos2 θ}{g}$
#
# $(S_x)'=0 ⇒ cos2 θ=0$
#
# $2θ_1=90 ⇒ θ_1 =45°$
#
# $2θ_2=270 ⇒ θ_2 =135°$

# %% [markdown]
# # **Opppgave 2 :**
# (a):
#
# $Σ \vec{F}=m \cdot \vec{a}$
#
# $N_m -G=N_m -mg=0$
#
# $N_v=mg=72.2 \cdot 9.81 ≈708 N$
#
#
# Mannen stiller seg så på vekta inne i en heis.
#
# ___
# (b):
#
# Kartene vil være samme siden vi har konstant fart. Altså a = 0
#
# $M= \frac{N_v}{g}=72.2 kg$
#
# ___
# (c):
#
#
# $Nv=Nm$
#
# $Nm -mg=ma$ : $a=3.2  \cdot m/s^2$
#
# $N_v=N_m=m(gta)$
#
# $M= \frac{N_v}{g}=\frac{m(gta)}{g}=95.7kg$

# %% [markdown]
# # **Oppgave3**
#
# (a):
#
# For å finne kraften fra mannen på vekta, bruker vi Newton 2:
#
# $F=-kx$
#
#
# N2:
#
# $Σ \vec{F}=ma ⇒ -kx =ma$
# - $a=\frac{d^2x}{dt^2}$
#
# $-kx =\frac{md^2x}{dt^2}$
#
# $\frac{-kx}{m} =\frac{d^2x}{dt^2}$
#
# $ ⇒ \frac{kx}{m} +\frac{d^2x}{dt^2}=0$
#
# ___
# (b):
#
#
# $w=\sqrt{\frac{k}{m}}=\sqrt{\frac{3250}{2}}=13.2/s$
#
# $T=\frac{2\cdot π}{w}=0.475 \cdot s$
#
# ___
# (c):
#
#
# $x(t)=X_m \cdot cos(wt+θ)$
#
# $X_m=\sqrt{x_0^2+(\frac{v_0}{w})^2}=0.07 \cdot m$
#
# $x(0.3)= 0.07 \cdot cos(13.23 \cdot 0.3) = -0.047 \cdot m$
#
# ___
# (d):
#
# $v(t)=\frac{dx}{dt}=-w\cdot X_m \cdot sin(wt+θ)$
# $ = -13.23 \cdot 0.07 \cdot sin(13.23t)$
#
# $= -0.926 \cdot sin(13.23t)$
